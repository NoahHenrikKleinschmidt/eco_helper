# %%
from eco_helper.core import *
import eco_helper.core.settings as settings
import os, glob
import pandas as pd
from alive_progress import alive_bar
import gseapy as gp

# %%
directory = "/data/users/noahkleinschmidt/EcoTyper/results/exports"

# %%
def enrichr( directory : str, outdir : str, gene_sets : list or str = "KEGG_2021_Human", organism : str = "human" ):
    """
    Perform gene set enrichment using `gseapy enrichr` for each cell type and each cell-state therein.

    Parameters
    ----------
    directory : str
        The path to the directory where extracted gene sets are stored in separate text files.
        Note, if both prerank and enrichr sets were extracted, this will automatically adjust to the `gseapy_enrichr` subdirectory if necessary.
    outdir : str
        The path to the output directory.
    gene_sets : list or str
        The gene sets to use for enrichment analysis. By default the latest KEGG gene sets are used.
    organism : str
        The organism to use for enrichment analysis. By default "human" is assumed.
    """

    if isinstance( gene_sets, str ):
        gene_sets = [gene_sets]

    directory, tmpdir, outdir = _enrichr_prep_directories(directory, outdir)
    
    files = os.listdir( directory )
    with alive_bar( len( files ), title = "Performing gseapy enrichr" ) as bar:
        for file in files:
            
            # perpare the filenames for enrichment analysis
            infile = os.path.join( directory, file )
            outfile = f"{file}{settings.enrichr_results_suffix}"

            # perform enrichr analysis
            gp.enrichr( 
                        gene_list = infile, 
                        outdir = tmpdir, 
                        gene_sets = gene_sets,
                        organism = organism,
                        no_plot = True,
                    )
            
            # merge the temporary files into one for each cell type and cell state
            textfiles = glob.glob( os.path.join( tmpdir, "*.txt" ) )
            textfiles = [ pd.read_csv( file, sep = "\t" ) for file in textfiles ]
            final = pd.concat( textfiles )
            final.to_csv( os.path.join( outdir, outfile ), sep = "\t", index = False )

            bar()

    # remove the temporary directory
    os.system( f"rm -r {tmpdir}" )

def _enrichr_prep_directories(directory, outdir):
    """
    Prepare the input and output directories for enrichr analysis. This will also create the tmpdir.

    Parameters
    ----------
    directory : str
        The path to the directory where extracted gene sets are stored in separate text files.
        Note, if both prerank and enrichr sets were extracted, this will automatically adjust to the `gseapy_enrichr` subdirectory if necessary.
    outdir : str
        The path to the output directory.
    """
    if settings.enrichr_outdir in os.listdir( directory ):
        directory = os.path.join( directory, settings.enrichr_outdir )
    
    if outdir == directory: 
        outdir = os.path.join( outdir, settings.gseapy_outdir )

    tmpdir = os.path.join( outdir, "__tmp" )
    if not os.path.exists( tmpdir ): 
        os.mkdir( tmpdir )
        
    return directory, tmpdir, outdir


enrichr( directory, directory, gene_sets = ["KEGG_2021_Human", "Reactome_2016"] )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /data/users/noahkleinschmidt/EcoTyper/eco_helper/eco_helper/enrich/_dev_enrich.ipynb Cell 3 in <cell line: 76>()
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a2249425528706572736f6e616c29227d/data/users/noahkleinschmidt/EcoTyper/eco_helper/eco_helper/enrich/_dev_enrich.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=70'>71</a>         os.mkdir( tmpdir )
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a2249425528706572736f6e616c29227d/data/users/noahkleinschmidt/EcoTyper/eco_helper/eco_helper/enrich/_dev_enrich.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=72'>73</a>     return directory, tmpdir, outdir
# ---> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a2249425528706572736f6e616c29227d/data/users/noahkleinschmidt/EcoTyper/eco_helper/eco_helper/enrich/_dev_enrich.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=75'>76</a> enrichr( directory, directory, gene_sets = ["KEGG_2021_Human", "Reactome_2016"] )
#
# /data/users/noahkleinschmidt/EcoTyper/eco_helper/eco_helper/enrich/_dev_enrich.ipynb Cell 3 in enrichr(directory, outdir, gene_sets, organism)
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a2249425528706572736f6e616c29227d/data/users/noahkleinschmidt/EcoTyper/eco_helper/eco_helper/enrich/_dev_enrich.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=20'>21</a> directory, tmpdir, outdir = _enrichr_prep_directories(directory, outdir)
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a2249425528706572736f6e616c29227d/data/users/noahkleinschmidt/EcoTyper/eco_helper/eco_helper/enrich/_dev_enrich.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=22'>23</a> files = os.listdir( directory )
# ---> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a2249425528706572736f6e616c29227d/data/users/noahkleinschmidt/EcoTyper/eco_helper/eco_helper/enrich/_dev_enrich.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=23'>24</a> with alive_bar( len( files ), title = "Performing gseapy enrichr" ) as bar:
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a2249425528706572736f6e616c29227d/data/users/noahkleinschmidt/EcoTyper/eco_helper/eco_helper/enrich/_dev_enrich.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=24'>25</a>     for file in files:
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a2249425528706572736f6e616c29227d/data/users/noahkleinschmidt/EcoTyper/eco_helper/eco_helper/enrich/_dev_enrich.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=25'>26</a>
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a2249425528706572736f6e616c29227d/data/users/noahkleinschmidt/EcoTyper/eco_helper/eco_helper/enrich/_dev_enrich.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=26'>27</a>         # perpare the filenames for enrichment analysis
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a2249425528706572736f6e616c29227d/data/users/noahkleinschmidt/EcoTyper/eco_helper/eco_helper/enrich/_dev_enrich.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=27'>28</a>         infile = os.path.join( directory, file )
#
# File ~/.conda/envs/EcoTyper/lib/python3.10/contextlib.py:135, in _GeneratorContextManager.__enter__(self)
#     133 del self.args, self.kwds, self.func
#     134 try:
# --> 135     return next(self.gen)
#     136 except StopIteration:
#     137     raise RuntimeError("generator didn't yield") from None
#
# File ~/.conda/envs/EcoTyper/lib/python3.10/site-packages/alive_progress/core/progress.py:276, in __alive_bar(config, total, calibrate, _cond, _sampling)
#     274 ctrl_c, bar = False, __AliveBarHandle(pause_monitoring, current, set_title, set_text)
#     275 set_text(), set_title()
# --> 276 start_monitoring()
#     277 try:
#     278     yield bar if not _sampling else locals()
#
# File ~/.conda/envs/EcoTyper/lib/python3.10/site-packages/alive_progress/core/progress.py:163, in __alive_bar.<locals>.start_monitoring(offset)
#     161 def start_monitoring(offset=0.):
#     162     term.hide_cursor()
# --> 163     hook_manager.install()
#     164     bar._handle = bar_handle
#     165     run.init = time.perf_counter() - offset
#
# File ~/.conda/envs/EcoTyper/lib/python3.10/site-packages/alive_progress/core/hook_manager.py:75, in buffered_hook_manager.<locals>.install()
#      72     yield from (logging.getLogger(name) for name in logging.root.manager.loggerDict)
#      74 # modify all stream handlers, including their subclasses.
# ---> 75 before_handlers.update({h: _set_stream(h, get_hook_for(h))  # noqa
#      76                         for logger in get_all_loggers()
#      77                         for h in logger.handlers if isinstance(h, StreamHandler)})
#      78 sys.stdout, sys.stderr = (get_hook_for(SimpleNamespace(stream=x)) for x in base)
#
# File ~/.conda/envs/EcoTyper/lib/python3.10/site-packages/alive_progress/core/hook_manager.py:75, in <dictcomp>(.0)
#      72     yield from (logging.getLogger(name) for name in logging.root.manager.loggerDict)
#      74 # modify all stream handlers, including their subclasses.
# ---> 75 before_handlers.update({h: _set_stream(h, get_hook_for(h))  # noqa
#      76                         for logger in get_all_loggers()
#      77                         for h in logger.handlers if isinstance(h, StreamHandler)})
#      78 sys.stdout, sys.stderr = (get_hook_for(SimpleNamespace(stream=x)) for x in base)
#
# File ~/.conda/envs/EcoTyper/lib/python3.10/site-packages/alive_progress/core/hook_manager.py:64, in buffered_hook_manager.<locals>.get_hook_for(handler)
#      62 def get_hook_for(handler):
#      63     if handler.stream:  # supports FileHandlers with delay=true.
# ---> 64         handler.stream.flush()
#      65     return SimpleNamespace(write=partial(write, handler.stream),
#      66                            flush=partial(flush, handler.stream),
#      67                            isatty=sys.stdout.isatty)
#
# File ~/.conda/envs/EcoTyper/lib/python3.10/site-packages/alive_progress/core/hook_manager.py:33, in buffered_hook_manager.<locals>.flush(stream)
#      32 def flush(stream):
# ---> 33     if buffers[stream]:
#      34         write(stream, '\n')
#      35         stream.flush()
#
# TypeError: unhashable type: 'types.SimpleNamespace'

# %%
source_results = "/data/users/noahkleinschmidt/EcoTyper/results/drop_hepato"

def assemble_enrichr_results( directory : str, cell_types : CellTypeCollection, outdir : str = None, remove_raw : bool = True ):
    """
    Assemble the per-state enrichr output text files into a single file per cell type. 

    Parameters
    ----------
    directory : str
        The directory storing the raw enrichr output files for each cell type and state.
    cell_types : CellTypeCollection
        The cell types to use for assembling the results.
    outdir : str
        The output directory to store the assembled results. 
        If not specified, the results will be stored in the same directory as the raw enrichr results.
    remove_raw : bool
        If True, the raw enrichr results will be removed after assembling.
    """
    if outdir is None:
        outdir = directory
    for cell_type in cell_types:
        
        # get the corresponding enrichr files
        files = glob.glob( os.path.join( directory, cell_type + "_*" ) )

        # get the states associated with each file by splitting through <cell_type>_<state>.txt.enrichr.txt
        states = [ i[ i.rfind( "_" ) + 1 : ].split(".")[0] for i in files ]

        # now read the dataframes and add the state
        dfs = [ pd.read_csv( file, sep = "\t" ) for file in files ]
        for df, state in zip(dfs, states): 
            df.insert( 0, settings.state_col, state ) 
        
        # concatenate and save the final dataframe
        final = pd.concat( dfs )
        outfile = os.path.join( outdir, f"{cell_type}{settings.enrichr_results_suffix}" )
        final.to_csv( outfile, sep = "\t", index = False )

        if remove_raw:
            files = " ".join( files )
            os.system( f"rm {files}" )
        
cell_types = CellTypeCollection( source_results )
assemble_enrichr_results( directory, cell_types )

# %%
def prerank( directory : str, outdir : str, gene_sets : list or str = "KEGG_2021_Human", organism : str = "human", min_size : int = 5, max_size = 500, permutations : int = 1000, **kwargs ):
    """
    Perform gene set enrichment using `gseapy prerank` for each cell type and each cell-state therein.

    Parameters
    ----------
    directory : str
        The path to the directory where extracted gene sets are stored in separate text files.
        Note, if both prerank and prerank sets were extracted, this will automatically adjust to the `gseapy_prerank` subdirectory if necessary.
    outdir : str
        The path to the output directory.
    gene_sets : list or str
        The gene sets to use for enrichment analysis. By default the latest KEGG gene sets are used.
    organism : str
        The organism to use for enrichment analysis. By default "human" is assumed.
    min_size : int
        The minimum number of genes required to be found in a gene set. 
    max_size : int
        The maximum number of genes allowed to be found in a gene set.
    permutations : int
        The number of permutations to use for the permutation test.
    **kwargs
        Any additional keyword arguments to pass to `gseapy.prerank`.
    """

    if isinstance( gene_sets, str ):
        gene_sets = [gene_sets]

    directory, tmpdir, outdir = _prerank_prep_directories(directory, outdir)
    
    files = os.listdir( directory )
    with alive_bar( len( files ), title = "Performing gseapy prerank" ) as bar:
        for file in files:
            
            # perpare the filenames for enrichment analysis
            infile = os.path.join( directory, file )
            outfile = f"{file}{settings.prerank_results_suffix}"

            # perform prerank analysis
            gp.prerank( 
                        rnk = infile, 
                        outdir = tmpdir, 
                        gene_sets = gene_sets,
                        organism = organism,
                        min_size = min_size,
                        max_size = max_size,
                        permutation_num = permutations,
                        no_plot = True,
                        **kwargs
                    )
            
            # merge the temporary files into one for each cell type and cell state
            # NOTE: prerank makes CSV files not TSV files!
            textfiles = glob.glob( os.path.join( tmpdir, "*.csv" ) )
            textfiles = [ pd.read_csv( file, sep = "," ) for file in textfiles ]
            final = pd.concat( textfiles )
            final.to_csv( os.path.join( outdir, outfile ), sep = "\t", index = False )

            bar()

    # remove the temporary directory
    os.system( f"rm -r {tmpdir}" )

def _prerank_prep_directories(directory, outdir):
    """
    Prepare the input and output directories for prerank analysis. This will also create the tmpdir.

    Parameters
    ----------
    directory : str
        The path to the directory where extracted gene sets are stored in separate text files.
        Note, if both prerank and prerank sets were extracted, this will automatically adjust to the `gseapy_prerank` subdirectory if necessary.
    outdir : str
        The path to the output directory.
    """
    if settings.prerank_outdir in os.listdir( directory ):
        directory = os.path.join( directory, settings.prerank_outdir )
    
    if outdir == directory: 
        outdir = os.path.join( outdir, settings.gseapy_outdir )

    tmpdir = os.path.join( outdir, "__tmp" )
    if not os.path.exists( tmpdir ): 
        os.mkdir( tmpdir )
        
    return directory, tmpdir, outdir


prerank( directory, directory, gene_sets = ["KEGG_2021_Human", "Reactome_2016"] )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /data/users/noahkleinschmidt/EcoTyper/eco_helper/eco_helper/enrich/_dev_enrich.ipynb Cell 5 in <cell line: 89>()
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a2249425528706572736f6e616c29227d/data/users/noahkleinschmidt/EcoTyper/eco_helper/eco_helper/enrich/_dev_enrich.ipynb#X26sdnNjb2RlLXJlbW90ZQ%3D%3D?line=83'>84</a>         os.mkdir( tmpdir )
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a2249425528706572736f6e616c29227d/data/users/noahkleinschmidt/EcoTyper/eco_helper/eco_helper/enrich/_dev_enrich.ipynb#X26sdnNjb2RlLXJlbW90ZQ%3D%3D?line=85'>86</a>     return directory, tmpdir, outdir
# ---> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a2249425528706572736f6e616c29227d/data/users/noahkleinschmidt/EcoTyper/eco_helper/eco_helper/enrich/_dev_enrich.ipynb#X26sdnNjb2RlLXJlbW90ZQ%3D%3D?line=88'>89</a> prerank( directory, directory, gene_sets = ["KEGG_2021_Human", "Reactome_2016"] )
#
# /data/users/noahkleinschmidt/EcoTyper/eco_helper/eco_helper/enrich/_dev_enrich.ipynb Cell 5 in prerank(directory, outdir, gene_sets, organism, min_size, max_size, permutations, **kwargs)
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a2249425528706572736f6e616c29227d/data/users/noahkleinschmidt/EcoTyper/eco_helper/eco_helper/enrich/_dev_enrich.ipynb#X26sdnNjb2RlLXJlbW90ZQ%3D%3D?line=28'>29</a> directory, tmpdir, outdir = _prerank_prep_directories(directory, outdir)
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a2249425528706572736f6e616c29227d/data/users/noahkleinschmidt/EcoTyper/eco_helper/eco_helper/enrich/_dev_enrich.ipynb#X26sdnNjb2RlLXJlbW90ZQ%3D%3D?line=30'>31</a> files = os.listdir( directory )
# ---> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a2249425528706572736f6e616c29227d/data/users/noahkleinschmidt/EcoTyper/eco_helper/eco_helper/enrich/_dev_enrich.ipynb#X26sdnNjb2RlLXJlbW90ZQ%3D%3D?line=31'>32</a> with alive_bar( len( files ), title = "Performing gseapy prerank" ) as bar:
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a2249425528706572736f6e616c29227d/data/users/noahkleinschmidt/EcoTyper/eco_helper/eco_helper/enrich/_dev_enrich.ipynb#X26sdnNjb2RlLXJlbW90ZQ%3D%3D?line=32'>33</a>     for file in files:
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a2249425528706572736f6e616c29227d/data/users/noahkleinschmidt/EcoTyper/eco_helper/eco_helper/enrich/_dev_enrich.ipynb#X26sdnNjb2RlLXJlbW90ZQ%3D%3D?line=33'>34</a>
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a2249425528706572736f6e616c29227d/data/users/noahkleinschmidt/EcoTyper/eco_helper/eco_helper/enrich/_dev_enrich.ipynb#X26sdnNjb2RlLXJlbW90ZQ%3D%3D?line=34'>35</a>         # perpare the filenames for enrichment analysis
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a2249425528706572736f6e616c29227d/data/users/noahkleinschmidt/EcoTyper/eco_helper/eco_helper/enrich/_dev_enrich.ipynb#X26sdnNjb2RlLXJlbW90ZQ%3D%3D?line=35'>36</a>         infile = os.path.join( directory, file )
#
# File ~/.conda/envs/EcoTyper/lib/python3.10/contextlib.py:142, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     140 if typ is None:
#     141     try:
# --> 142         next(self.gen)
#     143     except StopIteration:
#     144         return False
#
# File ~/.conda/envs/EcoTyper/lib/python3.10/site-packages/alive_progress/core/progress.py:284, in __alive_bar(config, total, calibrate, _cond, _sampling)
#     282         raise
#     283 finally:
# --> 284     stop_monitoring()
#     285     if thread:  # lets the internal thread terminate gracefully.
#     286         local_copy, thread = thread, None
#
# File ~/.conda/envs/EcoTyper/lib/python3.10/site-packages/alive_progress/core/progress.py:170, in __alive_bar.<locals>.stop_monitoring()
#     168 def stop_monitoring():
#     169     term.show_cursor()
# --> 170     hook_manager.uninstall()
#     171     bar._handle = None
#     172     return time.perf_counter() - run.init
#
# File ~/.conda/envs/EcoTyper/lib/python3.10/site-packages/alive_progress/core/hook_manager.py:85, in buffered_hook_manager.<locals>.uninstall()
#      82 buffers.clear()
#      83 sys.stdout, sys.stderr = base
# ---> 85 [_set_stream(handler, original_stream)
#      86  for handler, original_stream in before_handlers.items()]
#      87 before_handlers.clear()
#
# File ~/.conda/envs/EcoTyper/lib/python3.10/site-packages/alive_progress/core/hook_manager.py:85, in <listcomp>(.0)
#      82 buffers.clear()
#      83 sys.stdout, sys.stderr = base
# ---> 85 [_set_stream(handler, original_stream)
#      86  for handler, original_stream in before_handlers.items()]
#      87 before_handlers.clear()
#
# File ~/.conda/envs/EcoTyper/lib/python3.10/site-packages/alive_progress/core/hook_manager.py:134, in _set_stream(handler, stream)
#     133 def _set_stream(handler, stream):
# --> 134     return handler.setStream(stream)
#
# File ~/.conda/envs/EcoTyper/lib/python3.10/logging/__init__.py:1124, in StreamHandler.setStream(self, stream)
#    1122 self.acquire()
#    1123 try:
# -> 1124     self.flush()
#    1125     self.stream = stream
#    1126 finally:
#
# File ~/.conda/envs/EcoTyper/lib/python3.10/logging/__init__.py:1084, in StreamHandler.flush(self)
#    1082 try:
#    1083     if self.stream and hasattr(self.stream, "flush"):
# -> 1084         self.stream.flush()
#    1085 finally:
#    1086     self.release()
#
# File ~/.conda/envs/EcoTyper/lib/python3.10/site-packages/alive_progress/core/hook_manager.py:33, in buffered_hook_manager.<locals>.flush(stream)
#      32 def flush(stream):
# ---> 33     if buffers[stream]:
#      34         write(stream, '\n')
#      35         stream.flush()
#
# TypeError: unhashable type: 'types.SimpleNamespace'

# %%
def assemble_prerank_results( directory : str, cell_types : CellTypeCollection, outdir : str = None, remove_raw : bool = True ):
    """
    Assemble the per-state prerank output text files into a single file per cell type. 

    Parameters
    ----------
    directory : str
        The directory storing the raw prerank output files for each cell type and state.
    cell_types : CellTypeCollection
        The cell types to use for assembling the results.
    outdir : str
        The output directory to store the assembled results. 
        If not specified, the results will be stored in the same directory as the raw prerank results.
    remove_raw : bool
        If True, the raw prerank results will be removed after assembling.
    """
    if outdir is None:
        outdir = directory
    for cell_type in cell_types:
        
        # get the corresponding prerank files
        files = glob.glob( os.path.join( directory, cell_type + "_*" ) )

        # get the states associated with each file by splitting through <cell_type>_<state>.txt.prerank.txt
        states = [ i[ i.rfind( "_" ) + 1 : ].split(".")[0] for i in files ]

        # now read the dataframes and add the state
        dfs = [ pd.read_csv( file, sep = "\t" ) for file in files ]
        for df, state in zip(dfs, states): 
            df.insert( 0, settings.state_col, state ) 
        
        # concatenate and save the final dataframe
        final = pd.concat( dfs )
        outfile = os.path.join( outdir, f"{cell_type}{settings.prerank_results_suffix}" )
        final.to_csv( outfile, sep = "\t", index = False )

        if remove_raw:
            files = " ".join( files )
            os.system( f"rm {files}" )

assemble_prerank_results( directory, cell_types )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /data/users/noahkleinschmidt/EcoTyper/eco_helper/eco_helper/enrich/_dev_enrich.ipynb Cell 6 in <cell line: 41>()
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a2249425528706572736f6e616c29227d/data/users/noahkleinschmidt/EcoTyper/eco_helper/eco_helper/enrich/_dev_enrich.ipynb#X43sdnNjb2RlLXJlbW90ZQ%3D%3D?line=37'>38</a>             files = " ".join( files )
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a2249425528706572736f6e616c29227d/data/users/noahkleinschmidt/EcoTyper/eco_helper/eco_helper/enrich/_dev_enrich.ipynb#X43sdnNjb2RlLXJlbW90ZQ%3D%3D?line=38'>39</a>             os.system( f"rm {files}" )
# ---> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a2249425528706572736f6e616c29227d/data/users/noahkleinschmidt/EcoTyper/eco_helper/eco_helper/enrich/_dev_enrich.ipynb#X43sdnNjb2RlLXJlbW90ZQ%3D%3D?line=40'>41</a> assemble_prerank_results( directory, cell_types )
#
# /data/users/noahkleinschmidt/EcoTyper/eco_helper/eco_helper/enrich/_dev_enrich.ipynb Cell 6 in assemble_prerank_results(directory, cell_types, outdir, remove_raw)
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a2249425528706572736f6e616c29227d/data/users/noahkleinschmidt/EcoTyper/eco_helper/eco_helper/enrich/_dev_enrich.ipynb#X43sdnNjb2RlLXJlbW90ZQ%3D%3D?line=16'>17</a> if outdir is None:
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a2249425528706572736f6e616c29227d/data/users/noahkleinschmidt/EcoTyper/eco_helper/eco_helper/enrich/_dev_enrich.ipynb#X43sdnNjb2RlLXJlbW90ZQ%3D%3D?line=17'>18</a>     outdir = directory
# ---> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a2249425528706572736f6e616c29227d/data/users/noahkleinschmidt/EcoTyper/eco_helper/eco_helper/enrich/_dev_enrich.ipynb#X43sdnNjb2RlLXJlbW90ZQ%3D%3D?line=18'>19</a> for cell_type in cell_types:
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a2249425528706572736f6e616c29227d/data/users/noahkleinschmidt/EcoTyper/eco_helper/eco_helper/enrich/_dev_enrich.ipynb#X43sdnNjb2RlLXJlbW90ZQ%3D%3D?line=19'>20</a>
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a2249425528706572736f6e616c29227d/data/users/noahkleinschmidt/EcoTyper/eco_helper/eco_helper/enrich/_dev_enrich.ipynb#X43sdnNjb2RlLXJlbW90ZQ%3D%3D?line=20'>21</a>     # get the corresponding prerank files
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a2249425528706572736f6e616c29227d/data/users/noahkleinschmidt/EcoTyper/eco_helper/eco_helper/enrich/_dev_enrich.ipynb#X43sdnNjb2RlLXJlbW90ZQ%3D%3D?line=21'>22</a>     files = glob.glob( os.path.join( directory, cell_type + "_*" ) )
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a2249425528706572736f6e616c29227d/data/users/noahkleinschmidt/EcoTyper/eco_helper/eco_helper/enrich/_dev_enrich.ipynb#X43sdnNjb2RlLXJlbW90ZQ%3D%3D?line=23'>24</a>     # get the states associated with each file by splitting through <cell_type>_<state>.txt.prerank.txt
#
# TypeError: 'module' object is not iterable
